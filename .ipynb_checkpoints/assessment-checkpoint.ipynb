# %%
import numpy as np

import pandas as pd
from pandas.plotting import table

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
pd.set_option('display.max_columns', 0)
pd.set_option('display.max_rows', 0)

# %%
data_path = r'C:\Users\DucTRung\Desktop\GitHub\Covid_19_and_Press_Freedom_Index_Analysis\wrangled_frame'

# %%
charts_path = r'C:\Users\DucTRung\Desktop\GitHub\Covid_19_and_Press_Freedom_Index_Analysis\charts'

# %%
df = pd.read_csv(data_path + "\\wrangled_f_5.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   169 non-null    object
#  1   total_cases               169 non-null    int64
#  2   total_deaths              150 non-null    float64
#  3   total_recovered           164 non-null    float64
#  4   total_tests               150 non-null    float64
#  5   cases/1m                  169 non-null    float64
#  6   deaths/1m                 150 non-null    float64
#  7   tests/1m                  150 non-null    float64
#  8   press_freedom_index_2020  169 non-null    float64
#  9   region                    169 non-null    object
#  10  continent                 169 non-null    object
# dtypes: float64(7), int64(1), object(3)
# memory usage: 14.6+ KB

# %% [markdown]
# # Handle missing values

# %%
df['total_deaths'] = df['total_deaths'].fillna(0)

# %%
df.isnull().sum()
# Out:
# country                      0
# total_cases                  0
# total_deaths                 0
# total_recovered              5
# total_tests                 19
# cases/1m                     0
# deaths/1m                   19
# tests/1m                    19
# press_freedom_index_2020     0
# region                       0
# continent                    0
# dtype: int64

# %% [markdown]
# # Categorical

# %%
cate_des = df.describe(include='object')

# %%
cate_des
# Out:
#        country          region continent
# count      169             169       169
# unique     169              20         6
# top     Cyprus  Eastern Africa    Africa
# freq         1              18        50

# %% [markdown]
# ## Summary
# * 169 countries
# * 20 regions (Mode-Western Asian_18)
# * 6 continent (Mode-Africa_50)

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(13, 5))

reg = df['region'].value_counts().index
reg_val = df['region'].value_counts().values

wedges, texts, autotexts = axs[0].pie(reg_val, autopct='%1.1f%%', wedgeprops=dict(width=0.7))
axs[0].legend(wedges, reg, title='Regions', loc='center right', bbox_to_anchor=(1, 0, .5, 1))
axs[0].set_title('Relative frequency of regions', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Relative frequency of continents')

# %%
con = df['continent'].value_counts().index
con_val = df['continent'].value_counts().values

# %%
fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(con_val, autopct='%1.1f%%', wedgeprops=dict(width=0.7))
ax.legend(wedges, con, title='Contients', loc='center left', bbox_to_anchor=(.8, 0, .5, 1))
ax.set_title('Relative Frequency of Continents', fontsize=15)

plt.savefig(charts_path + '\\rel_fre_con.jpg')

# %% [markdown]
# # Numerical

# %%
def describe_numerical(df, stats):
    d = df.describe(include='number', percentiles=[.25, .5, .75, .90])
    d_plus = df[d.columns].agg(stats)
    return pd.concat([d, d_plus])

# %%
num_des = describe_numerical(df, ['sum'])

# %%
num_des.drop(['std', '25%', '75%'], inplace=True)

# %%
num_des
# Out:
#         total_cases   total_deaths  total_recovered  ...    deaths/1m      tests/1m  press_freedom_index_2020
# count  1.690000e+02     150.000000     1.640000e+02  ...   150.000000  1.500000e+02                169.000000
# mean   2.213106e+04    1724.386667     7.595177e+03  ...    42.303800  1.434636e+04                 34.539882
# std    1.021121e+05    7394.854380     2.573319e+04  ...   113.603159  2.239328e+04                 15.038585
# min    3.000000e+00       1.000000     1.000000e+00  ...     0.030000  4.000000e+00                  7.840000
# 25%    1.990000e+02       9.250000     7.300000e+01  ...     1.000000  7.982500e+02                 23.930000
# 50%    1.329000e+03      40.000000     4.815000e+02  ...     4.000000  5.127000e+03                 31.620000
# 75%    8.480000e+03     262.500000     2.067750e+03  ...    19.750000  1.893150e+04                 43.420000
# 90%    3.057700e+04    1866.200000     1.318950e+04  ...    87.200000  3.937950e+04                 55.346000
# max    1.238052e+06   72284.000000     2.006690e+05  ...   720.000000  1.504650e+05                 83.500000
# sum    3.740149e+06  258658.000000     1.245609e+06  ...  6345.570000  2.151954e+06               5837.240000
#
# [10 rows x 8 columns]

# %% [markdown]
# ## Total_cases

# %%
def stats(group):
    return {'count': group.count(),
        'sum': group.sum(),
            'mean': group.mean(),
            'median': group.median(),
            'max': group.max(),
            'min': group.min()}

# %%
case_s = df['total_cases']
bins = np.array([0, 10, 100, 1000, 10000, 100000, 1000000, 1500000])
labels = pd.cut(case_s, bins)
case_stat_t = case_s.groupby(labels).apply(stats).unstack()

# %%
case_stat_t
# Out:
#                     count        sum          mean     median        max        min
# total_cases
# (0, 10]               5.0       36.0  7.200000e+00        8.0       10.0        3.0
# (10, 100]            26.0     1183.0  4.550000e+01       37.5       99.0       11.0
# (100, 1000]          49.0    22941.0  4.681837e+02      471.0      900.0      101.0
# (1000, 10000]        50.0   190964.0  3.819280e+03     2842.5     9938.0     1022.0
# (10000, 100000]      29.0   777828.0  2.682166e+04    21983.0    82883.0    10004.0
# (100000, 1000000]     9.0  1509145.0  1.676828e+05   167007.0   250561.0   101650.0
# (1000000, 1500000]    1.0  1238052.0  1.238052e+06  1238052.0  1238052.0  1238052.0

# %%
case_s.mean()
# Out:
# 22131.059171597633

# %%
case_stat_t['count'].plot(kind='barh')
plt.title('Distribution of Countries by Number of Cases', fontsize=15)
plt.ylabel('Number of Cases')
plt.yticks(rotation=45)

plt.savefig(charts_path + '\\dis_coun_case.jpg', bbox_inches='tight')

# %% [markdown]
# ## Total_deaths

# %%
death_s = df['total_deaths']

# %%
bins = np.array([0, 10, 100, 1000, 10000, 100000])
labels = pd.cut(death_s, bins)
death_stats_t = death_s.groupby(labels).apply(stats).unstack()

# %%
death_stats_t
# Out:
#                  count       sum          mean   median      max      min
# total_deaths
# (0, 10]           46.0     241.0      5.239130      4.5     10.0      1.0
# (10, 100]         48.0    1950.0     40.625000     31.5     99.0     11.0
# (100, 1000]       34.0   11411.0    335.617647    256.5    895.0    102.0
# (1000, 10000]     17.0   62886.0   3699.176471   2854.0   8339.0   1074.0
# (10000, 100000]    5.0  182170.0  36434.000000  29315.0  72284.0  25531.0

# %%
death_s[death_s == 0].count()
# Out:
# 19

# %%
# death_stats_t['count'].plot(kind='barh')
plt.barh(y='[ 0 ]', width=19, label='No deaths', color='orange')
plt.barh(y=death_stats_t.index.astype(str), width=death_stats_t['count'])

plt.title('Distribution of Countries by Number of Deaths', fontsize=15)
plt.ylabel('Number of Deaths')
plt.yticks(rotation=45)
plt.legend()

plt.savefig(charts_path + '\\dis_coun_death.jpg', bbox_inches='tight')

# %% [markdown]
# ## press_freedom_index_2019

# %%
press_s = df['press_freedom_index_2020']

# %%
bins = np.array([0, 12.61, 23.99, 34.35, 54.11, 100])
labels = pd.cut(press_s, bins)
grouped = press_s.groupby(labels)

# %%
pfi_bins_f = grouped.apply(stats).unstack().reset_index().set_index(pd.Index(['Free', 'Upper Average', 'Average', 'Lower Average', 'Not Free']))

# %%
pfi_bins_f
# Out:
#               press_freedom_index_2020  count      sum       mean  median    max    min
# Free                      (0.0, 12.61]   14.0   147.23  10.516429  10.575  12.61   7.84
# Upper Average           (12.61, 23.99]   30.0   632.08  21.069333  22.525  23.99  15.12
# Average                 (23.99, 34.35]   58.0  1762.45  30.387069  29.970  34.34  25.91
# Lower Average           (34.35, 54.11]   46.0  1976.57  42.968913  43.080  54.11  35.06
# Not Free                (54.11, 100.0]   21.0  1318.91  62.805238  58.480  83.50  55.23

# %% [markdown]
# ### Create new feature: "Press_Freedom_Category"

# %%
df.insert(df.shape[1], column='pfi_category', value=np.random.normal(size=df.shape[0]))

# %%
df.loc[(df['press_freedom_index_2020'] >=0) & (df['press_freedom_index_2020'] <=12.61), 'pfi_category'] = 'free'

# %%
df.loc[(df['press_freedom_index_2020'] >12.61) & (df['press_freedom_index_2020'] <=23.99), 'pfi_category'] = 'upper_average'

# %%
df.loc[(df['press_freedom_index_2020'] >23.99) & (df['press_freedom_index_2020'] <=34.35), 'pfi_category'] = 'average'

# %%
df.loc[(df['press_freedom_index_2020'] >34.35) & (df['press_freedom_index_2020'] <=54.11), 'pfi_category'] = 'lower_average'

# %%
df.loc[(df['press_freedom_index_2020'] >54.11), 'pfi_category'] = 'not_free'

# %%
df.to_csv(data_path + "\\wrangled_6.csv", index=False)

# %%
def func(pct, data):
    absolute = int((pct)/100*np.sum(data+.5))
    return "{:.1f}%\n({:d})".format(pct, absolute)

# %%
data = pfi_bins_f['count'].values
labels = pfi_bins_f.index.values

# %%
plt.pie(data, autopct=lambda pct: func(pct, data))
plt.legend(labels, loc='upper right', bbox_to_anchor=(.8, 0, .5, 1))
plt.ylabel(" ")
plt.title("Number of Countries in Each Press Freedom Category", fontsize=13)

plt.savefig(charts_path + '\\dis_coun_pfi_type.jpg')

# %%
sns.distplot(press_s, kde=False)
plt.axvline(press_s.mean(), color='red')
plt.title('Histogram of Press-Freedom Index 2020', fontsize=15)
plt.text(s=('Average score: ' + str(round(press_s.mean(), 2))), x=press_s.mean()+3, y=50, bbox=dict(facecolor='r', alpha=.5))
plt.ylabel('Number of countries')
plt.savefig(charts_path + '\\his_pfi.jpg')

# %% [markdown]
# # Epidemic Status

# %%
epidemic_f = df[['total_cases', 'total_deaths', 'total_recovered', 'cases/1m', 'deaths/1m', 'continent', 'country', 'press_freedom_index_2020']]

# %%
epidemic_f = epidemic_f.set_index('country')

# %% [markdown]
# ## by Country

# %% [markdown]
# ### Cases/1m

# %%
epidemic_f['cases/1m'].sort_values(ascending=False)[:20].plot(kind='barh')
plt.title('Top 10 Highest Cases over 1 Million Population', fontsize=15)
plt.ylabel(' ')
plt.yticks(rotation=25)

plt.savefig(charts_path + '\\top_case_1m.jpg', bbox_inches='tight')

# %% [markdown]
# ### Deaths/1m

# %%
epidemic_f['deaths/1m'].sort_values(ascending=False)[:20].plot(kind='barh')
plt.title('Top 10 Highest Deaths over 1 Million Population', fontsize=15)
plt.ylabel(' ')
plt.yticks(rotation=25)

plt.savefig(charts_path + '\\top_dea_1m.jpg', bbox_inches='tight')

# %% [markdown]
# ### Total Cases

# %%
epidemic_f['cases_rel_fre'] = (epidemic_f['total_cases'] / epidemic_f['total_cases'].sum()) * 100

# %%
epidemic_f['cases_cum_fre'] = epidemic_f['cases_rel_fre'].cumsum()

# %%
x = 80 
list_ = list(abs(epidemic_f['cases_cum_fre'] - x))
print(list_.index(min(list_))+1)
# Out:
# 14

# %%
case_80_pct_f = epidemic_f[:list_.index(min(list_))+1][['total_cases', 'cases_cum_fre' , 'press_freedom_index_2020']]

# %%
mean_pfi_case_80_pct = case_80_pct_f['press_freedom_index_2020'].mean()

# %%
sum_case_20_pct = epidemic_f[14:]['total_cases'].sum()

# %%
mean_pfi_case_20_pct = epidemic_f[14:]['press_freedom_index_2020'].mean()

# %%
case_20_pct_f = pd.DataFrame(index=['The Rest'], data={'total_cases': sum_case_20_pct, 
                                       'cases_cum_fre': 100,
                                       'press_freedom_index_2020': mean_pfi_case_20_pct})

# %%
case_80_pct_f = pd.concat([case_80_pct_f, case_20_pct_f])

# %%
fig, ax = plt.subplots(ncols=1, nrows= 1, figsize=(8,4))

ax.bar(x=case_80_pct_f[:14].index, height=case_80_pct_f[:14]['total_cases'], label=(str(round(mean_pfi_case_80_pct, 2))))
ax.set_xticklabels(labels=case_80_pct_f.index.values, rotation=25)
ax.set_ylabel('Total Cases')
ax.set_title('Countries contain 80% cases over the world', fontsize=14)

ax.bar(x='The rest', height=sum_case_20_pct, color='orange', label=(str(round(mean_pfi_case_20_pct,2))))
ax.legend(title='Average Press Freedom Score', loc='upper center')

ax1 = ax.twinx()
ax1.plot(case_80_pct_f.index, case_80_pct_f['cases_cum_fre'], color='g', marker='D')
ax1.set_yticklabels(labels=" ")
for i, j in enumerate(case_80_pct_f['cases_cum_fre']):
    ax1.text(i+.3, j-1, s=str(round(j, 2))+'%')
    
plt.savefig(charts_path + '\\case_pareto.jpg')

# %% [markdown]
# ### Total Deaths

# %%
death_f = epidemic_f.sort_values(by='total_deaths', ascending=False)

# %%
death_f['deaths_rel_fre'] = (death_f['total_deaths'] / death_f['total_deaths'].sum()) * 100

# %%
death_f['deaths_cum_fre'] = death_f['deaths_rel_fre'].cumsum()

# %%
x = 80 
list_ = list(abs(death_f['deaths_cum_fre'] - x))
print(list_.index(min(list_)))
death_f[:list_.index(min(list_))+1]
# Out:
# 7
#          total_cases  total_deaths  cases/1m  deaths/1m  ... cases_rel_fre  cases_cum_fre  deaths_rel_fre  deaths_cum_fre
# country                                                  ...
# USA          1238052       72284.0    3740.0      218.0  ...     33.101676      33.101676       27.945782       27.945782
# UK            194990       29427.0    2872.0      433.0  ...      5.213429      50.709638       11.376799       39.322580
# Italy         213013       29315.0    3523.0      485.0  ...      5.695308      45.496209       11.333498       50.656079
# Spain         250561       25613.0    5359.0      548.0  ...      6.699225      39.800901        9.902265       60.558343
# France        170551       25531.0    2613.0      391.0  ...      4.560005      55.269643        9.870563       70.428906
# Belgium        50781        8339.0    4382.0      720.0  ...      1.357727      80.052854        3.223948       73.652854
# Brazil        115953        7958.0     546.0       37.0  ...      3.100224      70.733733        3.076649       76.729504
# Germany       167007        6993.0    1993.0       83.0  ...      4.465250      59.734893        2.703570       79.433074
#
# [8 rows x 10 columns]

# %%
death_80_pct_f = death_f[:list_.index(min(list_))+1][['total_deaths', 'deaths_cum_fre' , 'press_freedom_index_2020']]

# %%
mean_pfi_death_80_pct = death_80_pct_f['press_freedom_index_2020'].mean()

# %%
sum_death_20_pct =death_f[list_.index(min(list_))+1:]['total_deaths'].sum()

# %%
mean_pfi_death_20_pct = death_f[list_.index(min(list_))+1:]['press_freedom_index_2020'].mean()

# %%
death_20_pct_f = pd.DataFrame(index=['The Rest'], data={'total_deaths': sum_death_20_pct, 
                                       'deaths_cum_fre': 100,
                                       'press_freedom_index_2020': mean_pfi_death_20_pct})

# %%
death_80_pct_f = pd.concat([death_80_pct_f, death_20_pct_f])

# %%
death_80_pct_f
# Out:
#           total_deaths  deaths_cum_fre  press_freedom_index_2020
# USA            72284.0       27.945782                 23.850000
# UK             29427.0       39.322580                 22.930000
# Italy          29315.0       50.656079                 23.690000
# Spain          25613.0       60.558343                 22.160000
# France         25531.0       70.428906                 22.920000
# Belgium         8339.0       73.652854                 12.570000
# Brazil          7958.0       76.729504                 34.050000
# Germany         6993.0       79.433074                 12.160000
# The Rest       53198.0      100.000000                 35.173354

# %%
fig, ax = plt.subplots(ncols=1, nrows= 1, figsize=(8,4))

ax.bar(x=death_80_pct_f[:8].index, height=death_80_pct_f[:8]['total_deaths'], label=(str(round(mean_pfi_death_80_pct, 2))))
ax.set_xticklabels(labels=death_80_pct_f.index.values, rotation=25)
ax.set_ylabel('Total Deaths')
ax.set_title('Countries Contain 80% Deaths over The World', fontsize=14)

ax.bar(x='The rest', height=sum_death_20_pct, color='orange', label=(str(round(mean_pfi_case_20_pct,2))))
ax.legend(title='Average Press Freedom Score', loc='upper center')

ax1 = ax.twinx()
ax1.plot(death_80_pct_f.index, death_80_pct_f['deaths_cum_fre'], color='g', marker='D')
ax1.set_yticklabels(labels=" ")
for i, j in enumerate(death_80_pct_f['deaths_cum_fre']):
    ax1.text(i+.3, j-1, s=str(round(j, 2))+'%')
    
plt.savefig(charts_path + '\\death_pareto.jpg')

# %%
fig, (ax0, ax2) = plt.subplots(ncols=2, nrows= 1, figsize=(14,4))

ax0.bar(x=case_80_pct_f[:14].index, height=case_80_pct_f[:14]['total_cases'], label=(str(round(mean_pfi_case_80_pct, 2))))
ax0.set_xticklabels(labels=case_80_pct_f.index.values, rotation=25)
ax0.set_ylabel('Total Cases')
ax0.set_title('Countries contain 80% cases over the world', fontsize=14)

ax0.bar(x='The rest', height=sum_case_20_pct, color='orange', label=(str(round(mean_pfi_case_20_pct,2))))
ax0.legend(title='Average Press Freedom Score', loc='upper center')

ax1 = ax0.twinx()
ax1.plot(case_80_pct_f.index, case_80_pct_f['cases_cum_fre'], color='g', marker='D')
ax1.set_yticklabels(labels=" ")
for i, j in enumerate(case_80_pct_f['cases_cum_fre']):
    ax1.text(i+.3, j-1, s=str(round(j, 2))+'%')
    
ax2.bar(x=death_80_pct_f[:8].index, height=death_80_pct_f[:8]['total_deaths'], label=(str(round(mean_pfi_death_80_pct, 2))))
ax2.set_xticklabels(labels=death_80_pct_f.index.values, rotation=25)
ax2.set_ylabel('Total Deaths')
ax2.set_title('Countries Contain 80% Deaths over The World', fontsize=14)

ax2.bar(x='The rest', height=sum_death_20_pct, color='orange', label=(str(round(mean_pfi_case_20_pct,2))))
ax2.legend(title='Average Press Freedom Score', loc='upper center')

ax3 = ax2.twinx()
ax3.plot(death_80_pct_f.index, death_80_pct_f['deaths_cum_fre'], color='g', marker='D')
ax3.set_yticklabels(labels=" ")
for i, j in enumerate(death_80_pct_f['deaths_cum_fre']):
    ax1.text(i+.3, j-1, s=str(round(j, 2))+'%')
    
plt.savefig(charts_path + '\\case_death_pareto.jpg')

# %% [markdown]
# ### Deaths by different range of cases

# %%
bins = np.array([0, 10, 100, 1000, 10000, 100000, 1000000, 1500000])
labels = pd.cut(death_f['total_cases'], bins)
grouped = death_f['total_deaths'].groupby(labels)
dea_gb_bins_case = pd.DataFrame(grouped.agg(np.sum))
case_stat_t = pd.merge(case_stat_t, dea_gb_bins_case, left_index=True, right_index=True)

# %%
case_stat_t
# Out:
#                     count        sum          mean     median        max        min  total_deaths
# total_cases
# (0, 10]               5.0       36.0  7.200000e+00        8.0       10.0        3.0           2.0
# (10, 100]            26.0     1183.0  4.550000e+01       37.5       99.0       11.0          42.0
# (100, 1000]          49.0    22941.0  4.681837e+02      471.0      900.0      101.0         685.0
# (1000, 10000]        50.0   190964.0  3.819280e+03     2842.5     9938.0     1022.0        6280.0
# (10000, 100000]      29.0   777828.0  2.682166e+04    21983.0    82883.0    10004.0       43053.0
# (100000, 1000000]     9.0  1509145.0  1.676828e+05   167007.0   250561.0   101650.0      136312.0
# (1000000, 1500000]    1.0  1238052.0  1.238052e+06  1238052.0  1238052.0  1238052.0       72284.0

# %%
bins = np.array([0, 10, 100, 1000, 10000, 100000, 1000000, 1500000])
labels = pd.cut(epidemic_f['total_cases'], bins)
grouped = epidemic_f['total_recovered'].groupby(labels)
rec_gb_bins_case = pd.DataFrame(grouped.agg(np.sum))
case_stat_t = pd.merge(case_stat_t, rec_gb_bins_case, left_index=True, right_index=True)

# %%
case_stat_t[['total_deaths', 'total_recovered']].div(case_stat_t['sum'], axis=0).plot(kind='barh')
plt.title('Death and Recovery over each sort of Case', fontsize=15)
plt.ylabel(' ')
plt.savefig(charts_path + '\\dea_rec_over_bins_case.jpg', bbox_inches='tight', quality=95)

# %% [markdown]
# ## by Continent

# %% [markdown]
# ### Bucket Sum

# %%
total_grouped = epidemic_f[['total_cases', 'total_deaths', 'total_recovered']].groupby(epidemic_f['continent'])

# %%
bucket_sum = total_grouped.sum()

# %%
bucket_sum
# Out:
#                total_cases  total_deaths  total_recovered
# continent
# Africa               48853        1906.0          16408.0
# Asia                593198       20602.0         318632.0
# Europe             1503708      144375.0         571816.0
# North America      1347956       79635.0         249179.0
# Oceania               8389         118.0           7322.0
# South America       238045       12022.0          82252.0

# %%
mean_dea_con = bucket_sum['total_deaths'].mean() / bucket_sum['total_cases'].mean()

# %%
mean_rec_con = bucket_sum['total_recovered'].mean() / bucket_sum['total_cases'].mean()

# %%
bucket_sum.div(bucket_sum['total_cases'], axis=0)[['total_deaths', 'total_recovered']].plot(kind='barh', stacked=False)
plt.title('Deaths and Recovery over Cases by Continent', fontsize=15)
plt.ylabel(' ')
plt.axvline(mean_dea_con, linestyle='--', label=('death_mean: ' + str(round(mean_dea_con, 2))))
plt.axvline(mean_rec_con, linestyle='--', c='orange',  label=('recovery_mean: ' + str(round(mean_rec_con, 2))))
plt.legend(loc='best')
plt.savefig(charts_path + '\\de_rec_over_case.jpg', bbox_inches='tight')

# %% [markdown]
# ### Bucket Mean

# %%
mean_grouped = epidemic_f[['cases/1m', 'deaths/1m', 'press_freedom_index_2020']].groupby(epidemic_f['continent'])

# %%
bucket_mean = mean_grouped.mean()

# %%
bucket_mean
# Out:
#                   cases/1m   deaths/1m  press_freedom_index_2020
# continent
# Africa           71.780000    1.721750                 38.238600
# Asia            548.056250    6.646341                 44.080625
# Europe         1992.350000  132.750000                 22.485750
# North America   598.466667   30.720000                 30.499333
# Oceania         149.975000    4.000000                 20.560000
# South America   491.083333   18.783333                 30.856667

# %% [markdown]
# ## by Region

# %%
grouped = epidemic_f.groupby('region')

# %%
bucket_sum = grouped.sum()

# %%
bucket_sum
# Out:
#                          total_cases  total_deaths  total_recovered  cases_rel_fre  cases_cum_fre
# region
# Australia & New Zealand       8363.0         118.0           7300.0       0.223601     195.478736
# Caribbean                    10855.0         452.0           3028.0       0.290229     493.967112
# Central America              37003.0        2856.0          18489.0       0.989346     779.805751
# Central Asia                  7679.0          56.0           3469.0       0.205313     395.376387
# Eastern Africa                4389.0         106.0           2036.0       0.117348    1797.813804
# Eastern Asia                110463.0        5454.0          93024.0       2.953438     560.308560
# Eastern Europe              245682.0        4431.0          45697.0       6.568776     921.089454
# Melanesia                       26.0           0.0             22.0       0.000695     199.996765
# Middle Africa                 4140.0         137.0           1241.0       0.110691     797.672900
# Northern Africa              19284.0        1195.0           6342.0       0.515594     589.471890
# Northern America           1300098.0       76327.0         227662.0      34.760594     110.428167
# Northern Europe             269495.0       34714.0          31467.0       7.205462     909.641300
# South America               238045.0       12022.0          82252.0       6.364586    1111.245007
# South-Eastern Asia           52793.0        1740.0          13366.0       1.411521    1071.254060
# Southern Africa               7611.0         149.0           2762.0       0.203495     295.849363
# Southern Asia               190197.0        8940.0         104110.0       5.085279     833.139482
# Southern Europe             509490.0       56699.0         249279.0      13.622185    1059.901678
# Western Africa               13429.0         319.0           4027.0       0.359050    1491.963047
# Western Asian               232066.0        4412.0         104663.0       6.204726    1711.068356
# Western Europe              479041.0       48531.0         245373.0      12.808073     651.211436

# %%
mean_dea_reg = bucket_sum['total_deaths'].mean() / bucket_sum['total_cases'].mean()
mean_rec_reg = bucket_sum['total_recovered'].mean() / bucket_sum['total_cases'].mean()

# %%
bucket_sum.div(bucket_sum['total_cases'], axis=0)[['total_deaths', 'total_recovered']].plot(kind='barh', figsize=(7, 5))
plt.title('Deaths and Recovery over Cases by Region', fontsize=15)
plt.ylabel(' ')
plt.axvline(mean_dea_con, linestyle='--', label=('death_mean: ' + str(round(mean_dea_con, 2))))
plt.axvline(mean_rec_con, linestyle='--', c='orange',  label=('recovery_mean: ' + str(round(mean_rec_con, 2))))
plt.legend(loc='best')
plt.savefig(charts_path + '\\de_rec_o_case_region.jpg', bbox_inches='tight')

# %% [markdown]
# # Press-Freedom index

# %%
press_f = df[['country', 'region', 'continent', 'press_freedom_index_2020', 'total_cases', 'total_deaths', 'cases/1m', 'deaths/1m']]

# %% [markdown]
# ## by Country

# %% [markdown]
# ### Top

# %%
press_top = press_f.set_index('country')['press_freedom_index_2020'].sort_values()

# %%
press_top[:20].plot(kind='bar', figsize=(9, 4))
plt.title('Top 20 Best Press-Freedom Score', fontsize=15)
plt.xticks(rotation=25)
plt.xlabel(' ')
plt.savefig(charts_path + '\\top20_pfi.jpg', bbox_inches='tight')

# %%
press_bottom = press_f.set_index('country')['press_freedom_index_2020'].sort_values(ascending=False)

# %%
press_bottom[:20].plot(kind='bar', figsize=(9,4))
plt.title('Top 20 Worst Press-Freedom Score', fontsize=15)
plt.xticks(rotation=65)
plt.xlabel(' ')
plt.savefig(charts_path + '\\bottom20_pfi.jpg', bbox_inches='tight', dpi='figure')

# %% [markdown]
# ## by Continent

# %%
press_con_f = press_f['press_freedom_index_2020'].groupby(press_f['continent']).apply(stats).unstack()

# %%
press_con_f
# Out:
#                count      sum       mean  median    max    min
# continent
# Africa          50.0  1911.93  38.238600  34.230  83.50  19.25
# Asia            48.0  2115.87  44.080625  43.480  78.48  20.45
# Europe          40.0   899.43  22.485750  22.795  49.75   7.84
# North America   15.0   457.49  30.499333  29.700  63.81  10.51
# Oceania          4.0    82.24  20.560000  22.070  27.41  10.69
# South America   12.0   370.28  30.856667  31.780  45.66  15.79

# %% [markdown]
# ### List of worst score countries by each continent

# %%
press_con_top_f = press_f.set_index(press_f['press_freedom_index_2020'].isin(press_con_f['max'])).loc[True].reset_index(drop=True)

# %%
press_con_top_f = pd.merge(press_con_top_f, press_con_f['mean'], left_on='continent', right_index=True)

# %%
press_con_top_f.set_index('continent', inplace=True)

# %%
press_con_f = pd.merge(press_con_f, press_con_top_f['country'], left_index=True, right_index=True)

# %% [markdown]
# ### List of best score countries by each region

# %%
press_con_bottom_f = press_f.set_index(press_f['press_freedom_index_2020'].isin(press_con_f['min'])).loc[True].reset_index(drop=True)

# %%
press_con_bottom_f = pd.merge(press_con_bottom_f, press_con_f['mean'], left_on='continent', right_index=True)

# %%
press_con_bottom_f.set_index('continent', inplace=True)

# %%
press_con_f = pd.merge(press_con_f, press_con_bottom_f['country'], left_index=True, right_index=True)

# %%
press_con_f.rename(columns={'country_x': 'worst_country', 'country_y': 'best_country'}, inplace=True)

# %%
press_con_f.sort_values(by='mean', inplace=True)

# %%
press_con_f
# Out:
#                count      sum       mean  median    max    min worst_country best_country
# continent
# Oceania          4.0    82.24  20.560000  22.070  27.41  10.69          Fiji  New Zealand
# Europe          40.0   899.43  22.485750  22.795  49.75   7.84       Belarus       Norway
# North America   15.0   457.49  30.499333  29.700  63.81  10.51          Cuba      Jamaica
# South America   12.0   370.28  30.856667  31.780  45.66  15.79     Venezuela      Uruguay
# Africa          50.0  1911.93  38.238600  34.230  83.50  19.25       Eritrea      Namibia
# Asia            48.0  2115.87  44.080625  43.480  78.48  20.45         China       Cyprus

# %% [markdown]
# ### Visualization

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(6,4))

for i in press_con_f.index:
    ax.barh(data=press_con_f.loc[i], y=i, width='mean', label=(press_con_f.loc[i][['best_country', 'worst_country']].values[0] +" - "+press_con_f.loc[i][['best_country', 'worst_country']].values[1]))

handles, labels = ax.get_legend_handles_labels()
plt.legend(reversed(handles), reversed(labels), title='Nations with Best and Worst Score', loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Avereage Press-Freedom Score 2020 by Continent', fontsize=14)
plt.savefig(charts_path + '\\pfi_con.jpg', bbox_inches='tight')

# %% [markdown]
# ## by Region

# %%
press_reg_f = press_f['press_freedom_index_2020'].groupby(press_f['region']).apply(stats).unstack()

# %%
press_reg_f
# Out:
#                          count       mean  median    max    min
# region
# Australia & New Zealand    2.0  15.450000  15.450  20.21  10.69
# Caribbean                  5.0  31.128000  27.900  63.81  10.51
# Central America            8.0  32.838750  32.760  48.20  10.53
# Central Asia               4.0  48.177500  53.590  55.34  30.19
# Eastern Africa            18.0  42.708333  38.625  83.50  27.68
# Eastern Asia               6.0  35.736667  29.235  78.48  23.70
# Eastern Europe            10.0  32.905000  31.000  49.75  22.67
# Melanesia                  2.0  25.670000  25.670  27.41  23.93
# Middle Africa              8.0  42.375000  41.285  56.38  33.92
# Northern Africa            6.0  47.628333  50.425  56.82  29.45
# Northern America           2.0  19.570000  19.570  23.85  15.29
# Northern Europe           10.0  13.616000  12.605  22.93   7.84
# South America             12.0  30.856667  31.780  45.66  15.79
# South-Eastern Asia        11.0  47.492727  44.940  74.71  29.90
# Southern Africa            3.0  21.740000  22.410  23.56  19.25
# Southern Asia              9.0  42.066667  41.940  64.81  28.90
# Southern Europe           12.0  26.269167  28.510  33.83  11.83
# Western Africa            15.0  30.212667  30.620  35.63  22.26
# Western Asian             18.0  44.873333  43.055  72.57  20.45
# Western Europe             8.0  14.873750  14.015  22.92   9.96

# %% [markdown]
# ### List of worst score countries by each region

# %%
press_reg_top_f = press_f.set_index(press_f['press_freedom_index_2020'].isin(press_reg_f['max'])).loc[True].reset_index(drop=True)

# %%
press_reg_top_f = pd.merge(press_reg_top_f, press_reg_f['mean'], left_on='region', right_index=True)

# %%
press_reg_top_f.sort_values(by='mean', inplace=True, ignore_index=True)

# %%
press_reg_top_f.set_index('region', inplace=True)

# %%
press_reg_f = pd.merge(press_reg_f, press_reg_top_f['country'], left_index=True, right_index=True)

# %% [markdown]
# ### List of best score countries by each region

# %%
press_reg_bottom_f = press_f.set_index(press_f['press_freedom_index_2020'].isin(press_reg_f['min'])).loc[True].reset_index(drop=True)

# %%
press_reg_bottom_f = pd.merge(press_reg_bottom_f, press_reg_f['mean'], left_on='region', right_index=True)

# %%
press_reg_bottom_f.sort_values(by='mean', ignore_index=True, inplace=True)

# %%
press_reg_bottom_f.set_index('region', inplace=True)

# %%
press_reg_f = pd.merge(press_reg_f, press_reg_bottom_f['country'], left_index=True, right_index=True)

# %%
press_reg_f.rename(columns={'country_x': 'worst_country', 'country_y': 'best_country'}, inplace=True)

# %%
press_reg_f.sort_values(by='mean', inplace=True)

# %% [markdown]
# ### Visualization

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(6,4))

for i in press_reg_f.index:
    ax.barh(data=press_reg_f.loc[i], y=i, width='mean', label=press_reg_f.loc[i][['best_country', 'worst_country']].values)

handles, labels = ax.get_legend_handles_labels()
plt.legend(reversed(handles), reversed(labels), title='Nations with Best and Worst Score', loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Avereage Press-Freedom Score 2020 by Region', fontsize=14)
plt.savefig(charts_path + '\\pfi_reg.jpg', bbox_inches='tight')

# %% [markdown]
# # Relationship between Epidemic status and Press-Freedom index

# %%
world_cases = df['total_cases'].sum()
world_deaths = df['total_deaths'].sum()
world_recovered = df['total_recovered'].sum()

# %%
df.head()
# Out:
#   country  total_cases  total_deaths  ...            region      continent   pfi_category
# 0     USA      1238052       72284.0  ...  Northern America  North America  upper_average
# 1   Spain       250561       25613.0  ...   Southern Europe         Europe  upper_average
# 2   Italy       213013       29315.0  ...   Southern Europe         Europe  upper_average
# 3      UK       194990       29427.0  ...   Northern Europe         Europe  upper_average
# 4  France       170551       25531.0  ...    Western Europe         Europe  upper_average
#
# [5 rows x 12 columns]

# %%
total_pfi_stat_t = df[['total_cases', 'total_deaths', 'total_tests', 'total_recovered']].groupby(df['pfi_category']).agg(np.mean)

# %%
total_pfi_stat_t
# Out:
#                 total_cases  total_deaths    total_tests  total_recovered
# pfi_category
# average         6367.275862    281.931034   74107.886792      2323.631579
# free           27691.428571   2044.071429  370318.142857     15970.076923
# lower_average  11535.913043    295.934783  292523.974359      3640.533333
# not_free       12185.380952    572.857143  127630.733333      8760.300000
# upper_average  73220.733333   6268.200000  631462.655172     19535.206897

# %% [markdown]
# ## Correlation with Top and Bottom Score

# %% [markdown]
# ### Top Press_freedom index

# %%
top_20_index = press_top[:20].index.values

# %%
top_20_index_f = df[df['country'].isin(top_20_index)]

# %%
top_20_index_f.head()
# Out:
#         country  total_cases  total_deaths  total_recovered  press_freedom_index_2020            region      continent
# 5       Germany     167007.0        6993.0         137400.0                     12.16    Western Europe         Europe
# 11       Canada      62046.0        4043.0          26993.0                     15.29  Northern America  North America
# 13      Belgium      50781.0        8339.0          12731.0                     12.57    Western Europe         Europe
# 15  Netherlands      41087.0        5168.0              0.0                      9.96    Western Europe         Europe
# 18  Switzerland      30009.0        1795.0          25400.0                     10.62    Western Europe         Europe

# %%
case_top = top_20_index_f['total_cases'].sum()

# %%
death_top = top_20_index_f['total_deaths'].sum()

# %%
rec_top = top_20_index_f['total_recovered'].sum()

# %%
mean_score_top = top_20_index_f['press_freedom_index_2020'].mean()

# %%
top_20_index_f[['total_cases', 'total_deaths', 'total_recovered']].corrwith(top_20_index_f['press_freedom_index_2020'])
# Out:
# total_cases        0.005749
# total_deaths      -0.041776
# total_recovered    0.046102
# dtype: float64

# %% [markdown]
# ### Bottom Press_freedom_index

# %%
bottom_20_index = press_bottom[:20].index.values

# %%
bottom_20_index_f = df[df['country'].isin(bottom_20_index)]

# %%
bottom_20_index_f.head()
# Out:
#          country  total_cases  total_deaths  total_recovered  press_freedom_index_2020           region continent
# 9           Iran     101650.0        6418.0          81587.0                     64.81    Southern Asia     Asian
# 10         China      82883.0        4633.0          77911.0                     78.48     Eastern Asia     Asian
# 17  Saudi Arabia      30251.0         200.0           5431.0                     62.14    Western Asian     Asian
# 47         Egypt       7201.0         452.0           1730.0                     56.82  Northern Africa    Africa
# 58       Bahrain       3720.0           8.0           1762.0                     60.13    Western Asian     Asian

# %%
case_bottom = bottom_20_index_f['total_cases'].sum()

# %%
death_bottom = bottom_20_index_f['total_deaths'].sum()

# %%
rec_bottom = bottom_20_index_f['total_recovered'].sum()

# %%
mean_score_bottom = bottom_20_index_f['press_freedom_index_2020'].mean()

# %%
bottom_20_index_f[['total_cases', 'total_deaths', 'total_recovered']].corrwith(bottom_20_index_f['press_freedom_index_2020'])
# Out:
# total_cases        0.268829
# total_deaths       0.259914
# total_recovered    0.309179
# dtype: float64

# %% [markdown]
# ### Visualization

# %%
data = {'total_cases': [case_top, case_bottom, (world_cases - (case_top + case_bottom))],
 'total_deaths': [death_top, death_bottom, (world_deaths - (death_top + death_bottom))],
 'total_recovered': [rec_top, rec_bottom, (world_recovered - (rec_top + rec_bottom))],
 'mean_pfi_score': [mean_score_top, mean_score_bottom, np.nan]}

# %%
top_bottom_f = pd.DataFrame(data=data, index=['top_20', 'bottom_20', 'the_rest'])

# %%
top_bottom_f
# Out:
#            total_cases  total_deaths  total_recovered  mean_pfi_score
# top_20        471729.0       33392.0         253865.0         12.1085
# bottom_20     235695.0       12012.0         173687.0         63.1840
# the_rest     3032725.0      213254.0         818057.0             NaN

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8, 8))

axs[0, 0].barh(y=top_bottom_f.index[0], width=top_bottom_f['mean_pfi_score'][0])
axs[0, 0].barh(y=top_bottom_f.index[1], width=top_bottom_f['mean_pfi_score'][1], color='C1')
axs[0, 0].set_title('Average Press-Freedom Score', fontsize=14)

wedges, _, _ = axs[0, 1].pie(top_bottom_f['total_cases'], autopct='%1.1f%%' )
axs[0, 1].set_title('Total Cases', fontsize=14)

wedges, _, _ = axs[1, 0].pie(top_bottom_f['total_deaths'], autopct='%1.1f%%' )
axs[1, 0].set_title('Total Deaths', fontsize=14)

wedges, _, _ = axs[1, 1].pie(top_bottom_f['total_recovered'], autopct='%1.1f%%' )
axs[1, 1].legend(wedges, top_bottom_f.index, loc="center left")
axs[1, 1].set_title('Total Recovered', fontsize=14)

plt.savefig(charts_path + '\\corr_top_bot_pfi.jpg')

# %% [markdown]
# ## Epidemic status by Press Freedom category

# %%
total_pfi_stat_t = pd.pivot_table(df, values=['total_cases', 'total_deaths', 'cases/1m', 'deaths/1m', 'press_freedom_index_2020'],
              index='pfi_category',
              aggfunc={'total_cases': [np.sum, np.mean],
                       'total_deaths': [np.sum, np.mean],
                       'cases/1m': np.mean,
                       'deaths/1m': np.mean,
                       'press_freedom_index_2020': np.mean})

# %%
total_pfi_stat_t = total_pfi_stat_t.reindex(['free', 'upper_average', 'average', 'lower_average', 'not_free'])

# %%
total_pfi_stat_t
# Out:
#                   cases/1m   deaths/1m press_freedom_index_2020   total_cases            total_deaths
#                       mean        mean                     mean          mean        sum         mean       sum
# pfi_category
# free           1972.071429  156.500000                10.516429  27691.428571   387680.0  2044.071429   28617.0
# upper_average  1644.396667  114.178571                21.069333  73220.733333  2196622.0  6268.200000  188046.0
# average         386.862069   12.965800                30.387069   6367.275862   369302.0   281.931034   16352.0
# lower_average   346.347826    4.800000                42.968913  11535.913043   530652.0   295.934783   13613.0
# not_free        464.223810    6.515556                62.805238  12185.380952   255893.0   572.857143   12030.0

# %% [markdown]
# ### Total Cases

# %%
total_pfi = total_pfi_stat_t[['total_cases', 'total_deaths']]

# %%
fig, axs = plt.subplots(ncols=2, nrows=1, sharey=True, figsize=(7, 4))
total_pfi.iloc[:, total_pfi.columns.get_level_values(1)=='mean']['total_cases'].plot(kind='barh', ax=axs[0], legend=False, title='Average Case')
total_pfi.iloc[:, total_pfi.columns.get_level_values(1)=='mean']['total_deaths'].plot(kind='barh', ax=axs[1], color='C1', legend=False, title='Average Death')
axs[0].set_ylabel(ylabel= " ")
plt.savefig(charts_path + '\\total_pfi_mean.jpg', bbox_inches='tight')

# %% [markdown]
# ### Over 1 m pop

# %%
o1m_pfi = total_pfi_stat_t[['cases/1m', 'deaths/1m']]

# %%
o1m_pfi
# Out:
#                   cases/1m   deaths/1m
#                       mean        mean
# pfi_category
# free           1972.071429  156.500000
# upper_average  1644.396667  114.178571
# average         386.862069   12.965800
# lower_average   346.347826    4.800000
# not_free        464.223810    6.515556

# %%
fig, axs = plt.subplots(ncols=4, nrows=1, sharey=True, figsize=(10, 4))

total_pfi.iloc[:, total_pfi.columns.get_level_values(1)=='mean']['total_cases'].plot(kind='barh', ax=axs[0], legend=False, title='Average Case')

total_pfi.iloc[:, total_pfi.columns.get_level_values(1)=='mean']['total_deaths'].plot(kind='barh', ax=axs[1], color='C1', legend=False, title='Average Death')

o1m_pfi.iloc[:, o1m_pfi.columns.get_level_values(1)=='mean']['cases/1m'].plot(kind='barh', ax=axs[2], color='C2', legend=False, title='Average Case over 1 mil')

o1m_pfi.iloc[:, o1m_pfi.columns.get_level_values(1)=='mean']['deaths/1m'].plot(kind='barh', ax=axs[3], color='C3', legend=False, title='Average Death over 1 mil')

axs[0].set_ylabel(ylabel= " ")

plt.savefig(charts_path + '\\total_pfi_mean.jpg', bbox_inches='tight')

# %% [markdown]
# ### Visualization

# %%
total_cases = [case_bin_1, case_bin_2, case_bin_3, case_bin_4, case_bin_5]

# %%
total_deaths = [death_bin_1, death_bin_2, death_bin_3, death_bin_4, death_bin_5]

# %%
total_recovery = [rec_bin_1, rec_bin_2, rec_bin_3, rec_bin_4, rec_bin_5]

# %%
data = {'total_cases': total_cases,
             'total_deaths': total_deaths,
             'total_recovered': total_recovery}

# %%
x = pd.DataFrame(data, index=press_bins_f.index.values)

# %%
press_bins_f = pd.merge(press_bins_f, x, left_index=True, right_index=True)

# %%
press_bins_f
# Out:
#               press_freedom_index_2020  count       mean  total_cases  total_deaths  total_recovered
# free                      (0.0, 12.61]   14.0  10.516429     387680.0       28617.0         207611.0
# upper_average           (12.61, 23.99]   30.0  21.069333    2196622.0      188046.0         566521.0
# average                 (23.99, 34.35]   58.0  30.387069     369302.0       16352.0         132447.0
# lower_average           (34.35, 54.11]   46.0  42.968913     530652.0       13613.0         163824.0
# not_free                (54.11, 100.0]   21.0  62.805238     255893.0       12030.0         175206.0

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(8,8))

axs[0, 0].barh(y=press_bins_f.index[0], width=press_bins_f['mean'][0])
axs[0, 0].barh(y=press_bins_f.index[1], width=press_bins_f['mean'][1])
axs[0, 0].barh(y=press_bins_f.index[2], width=press_bins_f['mean'][2])
axs[0, 0].barh(y=press_bins_f.index[3], width=press_bins_f['mean'][3])
axs[0, 0].barh(y=press_bins_f.index[4], width=press_bins_f['mean'][4])
axs[0, 0].set_title('Average Press-Freedom Score', fontsize= 13)
axs[0, 0].set_yticklabels(labels= press_bins_f.index,rotation=45)

wedges, _, _ = axs[0, 1].pie(press_bins_f['total_cases'], autopct='%1.1f%%')
axs[0, 1].set_title('Total Cases', fontsize= 13)

wedges, _, _ = axs[1, 0].pie(press_bins_f['total_deaths'], autopct='%1.1f%%')
axs[1, 0].set_title('Total Deaths', fontsize= 13)

wedges, _, _ = axs[1, 1].pie(press_bins_f['total_recovered'], autopct='%1.1f%%')
axs[1, 1].set_title('Total Recovered', fontsize= 13)
axs[1, 1].legend(wedges, press_bins_f.index, loc="upper left", bbox_to_anchor=(-0.4, 0.5, -0.5, 0.5))

plt.savefig(charts_path + '\\dist_epi_pri.jpg')

# %% [markdown]
# ## by Continent

# %%
epi_reg_f = pd.DataFrame()
for i in press_con_f.index.values:
    x = pd.DataFrame(map(lambda x: x.sum() , [df[df['continent'] == i][j] for j in [['total_cases', 'total_deaths', 'total_recovered']]]), index=[i])
    epi_reg_f = epi_reg_f.append(x)

# %%
pfi_epi_con_f = pd.merge(press_con_f, epi_reg_f, left_index=True, right_index=True)

# %%
pfi_epi_con_f.sort_values(by='mean', inplace=True)

# %%
pfi_epi_con_f
# Out:
#                count       mean  median    max  ...  best_country total_cases total_deaths  total_recovered
# Oceania          4.0  20.560000  22.070  27.41  ...   New Zealand      8389.0        118.0           7322.0
# Europe          40.0  22.485750  22.795  49.75  ...        Norway   1503708.0     144375.0         571816.0
# North America   15.0  30.499333  29.700  63.81  ...       Jamaica   1347956.0      79635.0         249179.0
# South America   12.0  30.856667  31.780  45.66  ...       Uruguay    238045.0      12022.0          82252.0
# Africa          50.0  38.238600  34.230  83.50  ...       Namibia     48853.0       1906.0          16408.0
# Asian           48.0  44.080625  43.480  78.48  ...        Cyprus    593198.0      20602.0         318632.0
#
# [6 rows x 10 columns]

# %% [markdown]
# ### Relative_fre

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(8,8))

for i in pfi_epi_con_f.index.values:
    axs[0, 0].barh(y=i, width=pfi_epi_con_f.loc[i]['mean'])
# axs[0, 0].barh(y=pfi_epi_con_f.index[1], width=pfi_epi_con_f['mean'][1])
# axs[0, 0].barh(y=pfi_epi_con_f.index[2], width=pfi_epi_con_f['mean'][2])
# axs[0, 0].barh(y=pfi_epi_con_f.index[3], width=pfi_epi_con_f['mean'][3])
# axs[0, 0].barh(y=pfi_epi_con_f.index[4], width=pfi_epi_con_f['mean'][4])
axs[0, 0].set_title('Average Press-Freedom Score', fontsize= 13)
axs[0, 0].set_yticklabels(labels= pfi_epi_con_f.index,rotation=45)

wedges, _, _ = axs[0, 1].pie(pfi_epi_con_f['total_cases'], autopct='%1.1f%%')
axs[0, 1].set_title('Total Cases', fontsize= 13)

wedges, _, _ = axs[1, 0].pie(pfi_epi_con_f['total_deaths'], autopct='%1.1f%%')
axs[1, 0].set_title('Total Deaths', fontsize= 13)

wedges, _, _ = axs[1, 1].pie(pfi_epi_con_f['total_recovered'], autopct='%1.1f%%')
axs[1, 1].set_title('Total Recovered', fontsize= 13)
axs[1, 1].legend(wedges, pfi_epi_con_f.index, loc="upper left", bbox_to_anchor=(-0.4, 0.5, -0.5, 0.5))

plt.savefig(charts_path + '\\dist_epi_pri_con.jpg')

# %% [markdown]
# ### Asia

# %% [markdown]
# ## by Region

# %%
epi_reg_f = pd.DataFrame()
for i in press_reg_f.index.values:
    x = pd.DataFrame(map(lambda x: x.sum(), [df[df['region'] == i][j] for j in [['total_cases', 'total_deaths', 'total_recovered']]]), index=[i])
    epi_reg_f = epi_reg_f.append(x)

# %%
press_reg_f = pd.merge(press_reg_f, epi_reg_f, left_index=True, right_index=True)

# %%
press_reg_f.sort_values(by='mean', inplace=True)

# %%
press_reg_f
# Out:
#                          count       mean  median    max  ...      best_country total_cases total_deaths  total_recovered
# Northern Europe           10.0  13.616000  12.605  22.93  ...            Norway    269495.0      34714.0          31467.0
# Western Europe             8.0  14.873750  14.015  22.92  ...       Netherlands    479041.0      48531.0         245373.0
# Australia & New Zealand    2.0  15.450000  15.450  20.21  ...       New Zealand      8363.0        118.0           7300.0
# Northern America           2.0  19.570000  19.570  23.85  ...            Canada   1300098.0      76327.0         227662.0
# Southern Africa            3.0  21.740000  22.410  23.56  ...           Namibia      7611.0        149.0           2762.0
# Melanesia                  2.0  25.670000  25.670  27.41  ...  Papua New Guinea        26.0          0.0             22.0
# Southern Europe           12.0  26.269167  28.510  33.83  ...          Portugal    509490.0      56699.0         249279.0
# Western Africa            15.0  30.212667  30.620  35.63  ...             Ghana     13429.0        319.0           4027.0
# South America             12.0  30.856667  31.780  45.66  ...           Uruguay    238045.0      12022.0          82252.0
# Caribbean                  5.0  31.128000  27.900  63.81  ...           Jamaica     10855.0        452.0           3028.0
# Central America            8.0  32.838750  32.760  48.20  ...        Costa Rica     37003.0       2856.0          18489.0
# Eastern Europe            10.0  32.905000  31.000  49.75  ...          Slovakia    245682.0       4431.0          45697.0
# Eastern Asia               6.0  35.736667  29.235  78.48  ...       South Korea    110463.0       5454.0          93024.0
# Southern Asia              9.0  42.066667  41.940  64.81  ...            Bhutan    190197.0       8940.0         104110.0
# Middle Africa              8.0  42.375000  41.285  56.38  ...            Angola      4140.0        137.0           1241.0
# Eastern Africa            18.0  42.708333  38.625  83.50  ...        Madagascar      4389.0        106.0           2036.0
# Western Asian             18.0  44.873333  43.055  72.57  ...            Cyprus    232066.0       4412.0         104663.0
# South-Eastern Asia        11.0  47.492727  44.940  74.71  ...       Timor-Leste     52793.0       1740.0          13366.0
# Northern Africa            6.0  47.628333  50.425  56.82  ...           Tunisia     19284.0       1195.0           6342.0
# Central Asia               4.0  48.177500  53.590  55.34  ...        Kyrgyzstan      7679.0         56.0           3469.0
#
# [20 rows x 10 columns]

# %% [markdown]
# ### Visualization

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(12,8))

for i in press_reg_f.index.values:
    axs[0, 1].barh(y=i, width=press_reg_f.loc[i]['mean'])
# axs[0, 0].barh(y=press_reg_f.index[1], width=press_reg_f['mean'][1])
# axs[0, 0].barh(y=press_reg_f.index[2], width=press_reg_f['mean'][2])
# axs[0, 0].barh(y=press_reg_f.index[3], width=press_reg_f['mean'][3])
# axs[0, 0].barh(y=press_reg_f.index[4], width=press_reg_f['mean'][4])
axs[0, 1].set_title('Average Press-Freedom Score', fontsize= 13)
axs[0, 1].set_yticklabels(labels=' ')

wedges, _, = axs[0, 0].pie(press_reg_f['total_cases'])
axs[0, 0].set_title('Total Cases', fontsize= 13)

wedges, _, = axs[1, 0].pie(press_reg_f['total_deaths'])
axs[1, 0].set_title('Total Deaths', fontsize= 13)

wedges, _, = axs[1, 1].pie(press_reg_f['total_recovered'])
axs[1, 1].set_title('Total Recovered', fontsize= 13)
axs[1, 1].legend(wedges, press_reg_f.index, loc="upper left", bbox_to_anchor=(-1, 0.5, -1, 1.5), title='Rank')

plt.savefig(charts_path + '\\dist_epi_pri_reg.jpg')
